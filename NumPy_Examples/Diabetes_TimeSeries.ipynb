# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import datetime as dt
from dateutil.relativedelta import relativedelta
from pandas.tseries.offsets import * #need this for offset

# %% [markdown]
# #Print first few lines of csv and Plot

# %%
df = pd.read_csv('CGM/new_glucose_3.csv',sep=',',parse_dates=[1],index_col=1)
print df.head(5)

df.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-3e6673bb74b9> in <module>()
#       2 print df.head(5)
#       3
# ----> 4 df.plot()
#
# /Users/quasiben/Research/ContinuumDev/Anacondas/INSTALL/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_frame(frame, x, y, subplots, sharex, sharey, use_index, figsize, grid, legend, rot, ax, style, title, xlim, ylim, logx, logy, xticks, yticks, kind, sort_columns, fontsize, secondary_y, **kwds)
#    1453                      logy=logy, sort_columns=sort_columns,
#    1454                      secondary_y=secondary_y, **kwds)
# -> 1455     plot_obj.generate()
#    1456     plot_obj.draw()
#    1457     if subplots:
#
# /Users/quasiben/Research/ContinuumDev/Anacondas/INSTALL/lib/python2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#     733         self._compute_plot_data()
#     734         self._setup_subplots()
# --> 735         self._make_plot()
#     736         self._post_plot_logic()
#     737         self._adorn_subplots()
#
# /Users/quasiben/Research/ContinuumDev/Anacondas/INSTALL/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _make_plot(self)
#    1104                     args = (ax, x, y, style)
#    1105
# -> 1106                 newline = plotf(*args, **kwds)[0]
#    1107                 lines.append(newline)
#    1108                 leg_label = label
#
# /Users/quasiben/Research/ContinuumDev/Anacondas/INSTALL/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    3994         lines = []
#    3995
# -> 3996         for line in self._get_lines(*args, **kwargs):
#    3997             self.add_line(line)
#    3998             lines.append(line)
#
# /Users/quasiben/Research/ContinuumDev/Anacondas/INSTALL/lib/python2.7/site-packages/matplotlib/axes.pyc in _grab_next_args(self, *args, **kwargs)
#     328                 return
#     329             if len(remaining) <= 3:
# --> 330                 for seg in self._plot_args(remaining, kwargs):
#     331                     yield seg
#     332                 return
#
# /Users/quasiben/Research/ContinuumDev/Anacondas/INSTALL/lib/python2.7/site-packages/matplotlib/axes.pyc in _plot_args(self, tup, kwargs)
#     287         ret = []
#     288         if len(tup) > 1 and is_string_like(tup[-1]):
# --> 289             linestyle, marker, color = _process_plot_format(tup[-1])
#     290             tup = tup[:-1]
#     291         elif len(tup) == 3:
#
# /Users/quasiben/Research/ContinuumDev/Anacondas/INSTALL/lib/python2.7/site-packages/matplotlib/axes.pyc in _process_plot_format(fmt)
#      94     # handle the multi char special cases and strip them from the
#      95     # string
# ---> 96     if fmt.find('--')>=0:
#      97         linestyle = '--'
#      98         fmt = fmt.replace('--', '')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'find'
#                       isig  glucose
# datetime
# 2010-03-24 09:51:00  22.59      258
# 2010-03-24 09:56:00  22.52      260
# 2010-03-24 10:01:00  22.23      258
# 2010-03-24 10:06:00  21.56      254
# 2010-03-24 10:11:00  20.79      246

# %% [markdown]
# #Data is ALWAYS messy

# %%
print df
print df.ix[39450:39470]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 52281 entries, 2010-03-24 09:51:00 to 2010-10-10 23:57:00
# Data columns:
# isig       52281  non-null values
# glucose    52281  non-null values
# dtypes: int64(1), object(1)
#                       isig  glucose
# datetime
# 2010-08-24 09:58:00   5.78       77
# 2010-08-24 10:03:00  14.46       84
# 2010-08-24 10:08:00  19.38      108
# 2010-08-24 10:13:00  19.92      125
# 2010-08-24 10:18:00   20.2      136
# 2010-08-24 10:23:00  20.34      141
# 2010-08-24 10:28:00  21.04      145
# 2010-08-24 10:33:00  22.54      151
# 2010-08-24 12:38:00    nil      314
# 2010-08-24 12:43:00    nil      288
# 2010-08-24 12:48:00    nil      290
# 2010-08-24 12:53:00    nil      276
# 2010-08-24 12:58:00    nil      270
# 2010-08-24 13:03:00    nil      270
# 2010-08-24 13:08:00    nil      274
# 2010-08-24 13:13:00    nil      274
# 2010-08-24 13:18:00    nil      288
# 2010-08-24 13:23:00    nil      292
# 2010-08-24 13:28:00    nil      290
# 2010-08-24 13:33:00    nil      286

# %% [markdown]
# #Pandas cleans data really well

# %%
df = pd.read_csv('CGM/new_glucose_3.csv',sep=',',parse_dates=[1],index_col=1,na_values='nil')
print df.head(5)

df.plot()
# Out:
#                       isig  glucose
# datetime
# 2010-03-24 09:51:00  22.59      258
# 2010-03-24 09:56:00  22.52      260
# 2010-03-24 10:01:00  22.23      258
# 2010-03-24 10:06:00  21.56      254
# 2010-03-24 10:11:00  20.79      246

# %% [markdown]
# Sensor needs to be replaced 3
# take sensor out 2 hours to recalibrate
# bg

# %%
Day Of Week Indexing Weekend warriors

# %% [markdown]
# #What to do with missing values?

# %%
print df.ix[39450:39470]
# Out:
#                       isig  glucose
# datetime
# 2010-08-24 09:58:00   5.78       77
# 2010-08-24 10:03:00  14.46       84
# 2010-08-24 10:08:00  19.38      108
# 2010-08-24 10:13:00  19.92      125
# 2010-08-24 10:18:00  20.20      136
# 2010-08-24 10:23:00  20.34      141
# 2010-08-24 10:28:00  21.04      145
# 2010-08-24 10:33:00  22.54      151
# 2010-08-24 12:38:00    NaN      314
# 2010-08-24 12:43:00    NaN      288
# 2010-08-24 12:48:00    NaN      290
# 2010-08-24 12:53:00    NaN      276
# 2010-08-24 12:58:00    NaN      270
# 2010-08-24 13:03:00    NaN      270
# 2010-08-24 13:08:00    NaN      274
# 2010-08-24 13:13:00    NaN      274
# 2010-08-24 13:18:00    NaN      288
# 2010-08-24 13:23:00    NaN      292
# 2010-08-24 13:28:00    NaN      290
# 2010-08-24 13:33:00    NaN      286

# %% [markdown]
# #Drop Missing Values

# %%
df.dropna(axis=0).ix[39450:39470]
# Out:
#                       isig  glucose
# datetime
# 2010-08-24 09:58:00   5.78       77
# 2010-08-24 10:03:00  14.46       84
# 2010-08-24 10:08:00  19.38      108
# 2010-08-24 10:13:00  19.92      125
# 2010-08-24 10:18:00  20.20      136
# 2010-08-24 10:23:00  20.34      141
# 2010-08-24 10:28:00  21.04      145
# 2010-08-24 10:33:00  22.54      151
# 2010-08-28 13:56:00  21.50      162
# 2010-08-28 14:01:00  21.18      160
# 2010-08-28 14:06:00  20.42      156
# 2010-08-28 14:11:00  19.92      152
# 2010-08-28 14:16:00  19.60      178
# 2010-08-28 14:21:00  18.88      173
# 2010-08-28 14:26:00  18.08      167
# 2010-08-28 14:31:00  17.10      160
# 2010-08-28 14:36:00  16.30      152
# 2010-08-28 14:41:00  15.74      146
# 2010-08-28 14:46:00  15.24      140
# 2010-08-28 14:51:00  14.66      135

# %% [markdown]
# #Fill Values with 0

# %%
df.fillna(0).ix[39460:39470]
# Out:
#                      isig  glucose
# datetime
# 2010-08-24 12:48:00     0      290
# 2010-08-24 12:53:00     0      276
# 2010-08-24 12:58:00     0      270
# 2010-08-24 13:03:00     0      270
# 2010-08-24 13:08:00     0      274
# 2010-08-24 13:13:00     0      274
# 2010-08-24 13:18:00     0      288
# 2010-08-24 13:23:00     0      292
# 2010-08-24 13:28:00     0      290
# 2010-08-24 13:33:00     0      286

# %% [markdown]
# #Interpolate Values

# %%
df = df.apply(pd.Series.interpolate)
print df.ix[39460:39470]
# Out:
#                           isig  glucose
# datetime
# 2010-08-24 12:48:00  22.537062      290
# 2010-08-24 12:53:00  22.536083      276
# 2010-08-24 12:58:00  22.535104      270
# 2010-08-24 13:03:00  22.534124      270
# 2010-08-24 13:08:00  22.533145      274
# 2010-08-24 13:13:00  22.532166      274
# 2010-08-24 13:18:00  22.531186      288
# 2010-08-24 13:23:00  22.530207      292
# 2010-08-24 13:28:00  22.529228      290
# 2010-08-24 13:33:00  22.528249      286

# %% [markdown]
# #Index by date, plot a month worth of data

# %%
df.ix['2010-10-04'].plot()

# %%
df.ix['2010-10-04':'2010-11-04'].plot()

# %% [markdown]
# pulling data out of pandas
#
# * df.values
# * df.to_records()
# * df.to_csv()
# * df.to_dict()
# * df.to_latex()

# %% [markdown]
# #Visualize highs and lows of the day with masked arrays

# %%
day = df.ix['2010-10-04']
highs = day[day['glucose'] > 150]
lows = day[day['glucose'] < 80]

fig, ax = plt.subplots()

day['glucose'].plot(style='k--',ax=ax)
highs['glucose'].plot(style='ro',ax=ax)
lows['glucose'].plot(style='bo',ax=ax)

# %% [markdown]
# #Indexing by built-in logic time chunks (micro, milli, sec, minute, hour, day, week, month)
#
# Investigate averages per hour, per day, etc

# %%
hour = df.index.hour
hour_g = df.groupby(hour).mean()
hour_g.plot(kind='bar')

day = df.index.day
day_g = df.groupby(day).mean()
day_g.plot(kind='bar')

# %% [markdown]
# #Resampling
# Investigate non-standard time-chunks: plot every 35 minutes

# %%
days = days = pd.DateOffset(days=1)
for i in range(1,5):
    df[dt.datetime(2010,10,04,0,0,0)+days*(i-1):dt.datetime(2010,10,04,0,0,0)+days*i].plot(subplots=True)


df_1min = df.resample('1Min',fill_method='pad')
min35 = pd.DateOffset(minutes=35)
for i in range(1,10):
    df_1min[dt.datetime(2010,10,10,0,0,0)+min45*(i-1):dt.datetime(2010,10,10,0,0,0)+min35*i].plot(subplots=True)

# %% [markdown]
# Computational Tools:
#
# * rolling_count	Number of non-null observations
# * rolling_sum	Sum of values
# * rolling_mean	Mean of values
# * rolling_median	Arithmetic median of values
# * rolling_window	Moving window function
# * ...

# %%
#rolling averages
fig, ax = plt.subplots()
df.ix['2010-10-04'].plot(style='k--',ax=ax)
pd.rolling_mean(df.ix['2010-10-04'],10).plot(style='g',ax=ax)

# %% [markdown]
# Bolus Wizard estimate how much insulin to deliver to bring down blood glucose.  User inputs estimate for carb
# (ESTIMATES how much insulin to deliever how much to deliever for every gram over carb, how many mml per dec of insulin should bring down the blood glucose
# rule of 1500
# grams/unit would require 11g/1 unit of insulin

# %%
bolus_df = pd.read_csv('bolus_wizard_estimate.csv',sep=',',parse_dates=[2],index_col=2,na_values='nil')

# %%
bolus_df.ix['2010-10-04']
# Out:
#                      target_high  active_estimate  target_low  bg_input  \
# datetime
# 2010-10-04 06:44:00          120              0.0          80       116
# 2010-10-04 12:30:00          120              0.0          80         0
# 2010-10-04 15:51:00          120              0.0          80       223
# 2010-10-04 18:22:00          120              0.2          80        61
# 2010-10-04 18:44:00          120              0.0          80         0
# 2010-10-04 21:23:00          120              0.2          80       333
# 2010-10-04 23:25:00          120              0.6          80       193
#
#                      insulin_sensitivity  carb_ratio  food_estimate  \
# datetime
# 2010-10-04 06:44:00                   80          11            3.6
# 2010-10-04 12:30:00                   80          13            5.0
# 2010-10-04 15:51:00                   80          13            0.0
# 2010-10-04 18:22:00                   80          13            3.7
# 2010-10-04 18:44:00                   80          13            1.6
# 2010-10-04 21:23:00                   80          13            0.0
# 2010-10-04 23:25:00                   80          18            0.0
#
#                      correction_estimate  carb_input  estimate
# datetime
# 2010-10-04 06:44:00                  0.0          40       3.6
# 2010-10-04 12:30:00                  0.0          65       5.0
# 2010-10-04 15:51:00                  1.2           0       1.2
# 2010-10-04 18:22:00                  0.3          49       3.4
# 2010-10-04 18:44:00                  0.0          22       1.6
# 2010-10-04 21:23:00                  2.6           0       2.4
# 2010-10-04 23:25:00                  0.9           0       0.3

# %%
bolus_df = pd.read_csv('bolus_wizard_estimate.csv',sep=',',parse_dates=[2],index_col=2,na_values='nil')
day = df.ix['2010-10-04']
highs = day[day['glucose'] > 150]
lows = day[day['glucose'] < 80]

bolus = bolus_df.ix['2010-10-04']
bolus['bg_input'] = bolus['bg_input']/2.0

fig, ax = plt.subplots()
day['glucose'].plot(style='k--',ax=ax)
highs['glucose'].plot(style='ro',ax=ax)
lows['glucose'].plot(style='bo',ax=ax)

bolus['carb_input'].plot(style='g',ax=ax)
bolus['bg_input'].plot(style='mx--',ax=ax)

# %% [markdown]
# under estimated the carbs correctly

# %%
grouped =bolus_df.groupby(['carb_ratio','target_high'])

# %%
grouped.groups.keys()
# Out:
# [(8.0, 120),
#  (15.0, 120),
#  (25.0, 120),
#  (12.0, 120),
#  (9.0, 120),
#  (15.0, 140),
#  (13.0, 140),
#  (18.0, 140),
#  (13.0, 120),
#  (10.0, 120),
#  (6.0, 120),
#  (16.0, 120),
#  (25.0, 150),
#  (15.0, 150),
#  (8.5, 120),
#  (20.0, 150),
#  (20.0, 120),
#  (6.5, 120),
#  (7.0, 120),
#  (12.0, 150),
#  (16.0, 140),
#  (15.0, 121),
#  (18.0, 120),
#  (14.0, 120),
#  (5.5, 120),
#  (24.0, 120),
#  (11.0, 120),
#  (28.0, 120)]

# %%
new_df = grouped.get_group((13,120))
new_df['bg_input']
# Out:
# datetime
# 2010-07-17 06:35:00     66
# 2010-07-17 08:28:00     65
# 2010-07-18 07:35:00     80
# 2010-07-18 07:52:00    136
# 2010-07-19 08:21:00      0
# 2010-07-20 07:51:00      0
# 2010-07-20 09:18:00    232
# 2010-07-21 07:48:00    108
# 2010-07-22 08:03:00      0
# 2010-07-23 09:22:00      0
# 2010-07-24 08:10:00      0
# 2010-07-25 09:58:00      0
# 2010-07-28 08:52:00    105
# 2010-08-02 08:11:00    135
# 2010-08-03 11:27:00    103
# ...
# 2012-05-12 19:13:00     82
# 2012-05-12 19:26:00      0
# 2012-05-12 20:27:00      0
# 2012-05-12 20:36:00      0
# 2012-05-13 19:46:00     87
# 2012-05-13 20:12:00      0
# 2012-05-14 18:18:00     75
# 2012-05-14 21:28:00    214
# 2012-05-15 19:02:00    116
# 2012-05-16 19:22:00    181
# 2012-05-17 17:45:00    163
# 2012-05-17 19:47:00     64
# 2012-05-17 21:15:00      0
# 2012-05-18 18:53:00    172
# 2012-05-18 19:01:00    172
# Name: bg_input, Length: 1655

# %%
new_df = grouped.get_group((13,150))
new_df['bg_input']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-2d61a3ca24eb> in <module>()
# ----> 1 new_df = grouped.get_group((13,150))
#       2 new_df['bg_input']
#
# /Users/quasiben/Research/ContinuumDev/Anacondas/INSTALL/lib/python2.7/site-packages/pandas/core/groupby.pyc in get_group(self, name, obj)
#     267             obj = self.obj
#     268
# --> 269         inds = self.indices[name]
#     270         return obj.take(inds, axis=self.axis)
#     271
#
# KeyError: (13, 150)
