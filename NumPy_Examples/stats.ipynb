# %%
import numpy as np

# %%
a = np.random.random(2000)

# %%
np.average(a)
# Out:
# 0.48928923914235523

# %%
np.mean(a)
# Out:
# 0.48928923914235523

# %%
np.median([1,1,1,1,1,1,1000000])
# Out:
# 1.0

# %%
np.mean([1,1,1,1,1,1,1000000])
# Out:
# 142858.0

# %%
np.std(a)
# Out:
# 0.28808548076599444

# %%
np.var(a)
# Out:
# 0.082993244228174154

# %%
a = np.random.randn(200)

# %%
pylab.plot(np.correlate(a, a, 'same'))
# Out:
# [&lt;matplotlib.lines.Line2D at 0x4f07a90&gt;]

# %%
import scipy as sp

# %%
import scipy.signal

# %%
a = np.random.randn(100, 1000)

# %%
b = sp.signal.lfilter(np.ones(20)/20., [1], a, axis=0)

# %%
pylab.imshow(np.cov(a))
# Out:
# &lt;matplotlib.image.AxesImage at 0x65420d0&gt;

# %%
pylab.imshow(np.cov(b))
# Out:
# &lt;matplotlib.image.AxesImage at 0x6df7190&gt;

# %%
a = np.random.randn(100,1000)

# %%
b = np.random.randn(2000)

# %%
np.histogram(b)
# Out:
# (array([  1,  10,  56, 199, 405, 562, 444, 234,  74,  15]), array([-4.02423848, -3.30334294, -2.5824474 , -1.86155186, -1.14065633,       -0.41976079,  0.30113475,  1.02203029,  1.74292583,  2.46382137,        3.1847169 ]))

# %%
pylab.hist(b)
# Out:
# (array([  1,  10,  56, 199, 405, 562, 444, 234,  74,  15]), array([-4.02423848, -3.30334294, -2.5824474 , -1.86155186, -1.14065633,       -0.41976079,  0.30113475,  1.02203029,  1.74292583,  2.46382137,        3.1847169 ]), &lt;a list of 10 Patch objects&gt;)
